# %% [markdown]
# # Morphometrics
#
# We will see how we can use any given surface from Badlands to extract several parameters relative to **morphometrics analysis**. The analysis relies only on the `tin` files (*i.e.* surface) produced by Badlands. If you are interested in looking at hydrometrics and stratigraphic analysis there are other notebooks specially designed for that in the **Badlands companion** repository.
#
# **Morphometrics** refers to quantitative description and analysis of the produced Badlands landforms which could be applied to a particular kind of landform or to drainage basins and large regions.
#
# The following suite of geomorphic attributes could be extracted:
# - **gradient**: magnitude of maximum gradient
# - **horizontal curvature** describes convergent or divergent fluxes
# - **vertical curvature**: positive values describe convex profile curvature, negative values concave profile.
# - **aspect**: direction of maximum gradient
# - **discharge**:  it relates to the drainage area
#
# In addition, the last section of this notebook shows how you can `slice` the model in any direction to plot a **profile** of the elevation.

# %%
# %matplotlib inline

import numpy as np
# Import badlands grid generation toolbox
from scripts import morphoGrid as morph

# display plots in SVG format
# %config InlineBackend.figure_format = 'svg'

# %% [markdown]
# # 1. Define analyse bounding box
#
# We first have to define the path to the Badlands outputs we want to analyse. In addition Badlands is creating several files for each processors that have been used, you need to specify this number in the `ncpus` variable.
#
# We then need to provide the extent of the area we want to perform morphometrics analysis on using the `bbox` parameters which is numpy array containing the extent in the following order [xlow,ylow,xup,yup].
#
# Finally you need to specify the resolution you want to work on. Usually Badlands model are ran on resolution of several hundred of metres but you might want to extract the morphemetrics attributes at a much higher resolution. This is done using the `dx` parameter which is in metres.
#
# For more information regarding the function uncomment the following line.

# %%
#help(morph.morphoGrid.__init__)
from matplotlib import pyplot as plt
import numpy as np

# %%
morpho = morph.morphoGrid(folder='Output_eualps_slope/h5', bbox = [0,0,50000,25000], dx=100)

# %% [markdown]
# # 2. Interpolation of TIN data
#
# We now interpolate the data from a particular time step (`timestep`) from the TIN to the regular grid, which extent and resolution have been specified in previous function.
#
# **Note**
#
# If you are interested in making some morphometric comparisons between different time steps you could create multiple instances of the morphometrics python class each of them associated to a given time step.

# %%
#help(morpho.loadHDF5)

# %%
morpho.loadHDF5(timestep=100)

# %% [markdown]
# ### Plot basic features

# %%
plt.imshow(morpho.z)

# %%
plt.imshow(morpho.discharge)

# %%
plt.imshow(morpho.z[35:-25,10:-10])

# %%
morpho.loadHDF5(timestep=100)

# %% [markdown]
# ## Compare Slopes

# %%
morpho2 = morph.morphoGrid(folder='Output_eualps_mila/h5', bbox = [0,0,50000,25000], dx=100)

# %%
morpho2.loadHDF5(timestep=100)

# %%
plt.figure(figsize= (10,8))
plt.imshow(morpho.z-morpho2.z)
plt.colorbar()
plt.title('Comparison of Slope Models')
# Out:
# Text(0.5, 1.0, 'Comparison of Slope Models')

# %% [markdown]
# ### Retrieve Data from .tin file

# %%
morpho = morph.morphoGrid(folder='output_SALPS_timetest_3/h5', bbox = [0,0,100000,50000], dx=150)
slope = []
for k in range(101):
    morpho.loadHDF5(timestep=k)
    slope.append(np.mean(morpho.discharge))

morpho2 = morph.morphoGrid(folder='output_SALPS_timetest_3/h5', bbox = [0,0,100000,50000], dx=150)
rain = []
for k in range(101):
    morpho2.loadHDF5(timestep=k)
    rain.append(np.mean(morpho2.discharge))
    
morpho3 = morph.morphoGrid(folder='output_SALPS_timetest_3/h5', bbox = [0,0,100000,50000], dx=150)
mila = []
for k in range(101):
    morpho3.loadHDF5(timestep=k)
    mila.append(np.mean(morpho3.discharge))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 morpho = morph.morphoGrid(folder='output_SALPS_timetest_3/h5', bbox = [0,0,100000,50000], dx=150)
#       2 slope = []
#       3 for k in range(101):
#
# File ~/Desktop/workspace/Trials/myDischarge/scripts/morphoGrid.py:57, in morphoGrid.__init__(self, folder, bbox, dx)
#      55 self.folder = folder
#      56 if not os.path.isdir(folder):
# ---> 57     raise RuntimeError('The given folder cannot be found or the path is incomplete.')
#      59 self.x = None
#      60 self.y = None
#
# RuntimeError: The given folder cannot be found or the path is incomplete.

# %%
# Assuming iceTHICK, slope, rain, and mila are all lists or arrays with 26 elements
iceTHICK = np.asarray(iceTHICK)
slope = np.asarray(slope)
rain = np.asarray(rain)
mila = np.asarray(mila)

# Create an array for the x-axis
x_values = np.arange(101)
plt.plot(x_values, slope, c='g', lw=2, label='Slope')
plt.plot(x_values, rain, c='b', lw=2, label='Rain')
plt.plot(x_values, mila, c='r', lw=2, label='Mila')
plt.legend()
plt.xlabel('Time Step [25]')
plt.ylabel('Discharge (m^3/s)')
plt.title('SALPS Comparison of Slope, Rain, and Mila Models')

# Show the plot
plt.show()

# %%
print("Slope")
for k in range(26):
    print(slope[k])

print("\nRain")
for k in range(26):
    print(rain[k])

print("\nMila")
for k in range(26):
    print(mila[k])

# %% [markdown]
# #### Comparison between Models

# %%
morpho = morph.morphoGrid(folder='output_EUALPS_slope/h5', bbox = [0,0,100000,50000], dx=150)
slope = []
for k in range(26):
    morpho.loadHDF5(timestep=k)
    slope.append(np.mean(morpho.discharge[10:-10,333:-10]))

morpho2 = morph.morphoGrid(folder='output_EUALPS_rain/h5', bbox = [0,0,100000,50000], dx=150)
rain = []
for k in range(26):
    morpho2.loadHDF5(timestep=k)
    rain.append(np.mean(morpho2.discharge[10:-10,333:-10]))
    
morpho3 = morph.morphoGrid(folder='output_EUALPS_mila/h5', bbox = [0,0,100000,50000], dx=150)
mila = []
for k in range(26):
    morpho3.loadHDF5(timestep=k)
    mila.append(np.mean(morpho3.discharge[10:-10,333:-10]))

# %% [markdown]
# ### Shape of the morphometric file

# %%
morpho.z.shape,morpho.x.max(),morpho.x.min(),morpho.y.max(),morpho.y.min()

# %%
#X Axis Coordinates to Morpho.Z shape converter
print(f"20k: ", (667/5))
print(f"40k: ", (667/5)*2)
print(f"60k: ", (667/5)*3)
print(f"80k: ", (667/5)*4)
print(f"100k: ", (667/5)*5)

# %% [markdown]
# # 3. Cross-sections analyses
#
# The last function provided here helps you to create a cross-section from 2 points (xo,yo) and (xm,ym). The create section will interpolate the attributes over the desired slice using a bivariate spline method.
#
# The resulting section is then plotted as a 2D scatter and line graph using **plotly** library.

# %%
morpho = morph.morphoGrid(folder='Output_eualps_slope/h5', bbox = [0,0,50000,25000], dx=250)

# %%
morpho.loadHDF5(timestep=100)

# %%
x_axis = False

# Number of cross-sections
nbCS = 8
# Number of points per cross-section
nbPts = 800
# Extent of the cross-section along Y-axis
ymin = 0.
ymax = 25000.
# Extent of the cross-section along X-axis
xmin = 0.
xmax = 50000.
# Define timestep and according time interval based on display time in the XML input file
timeStp = [1, 5, 10]
timeMA = list(map(lambda x: x * 0.01, timeStp))

# %% [markdown]
# Now that we have defined the parameters we use the following loop to create the averaged representation at each time step of the landscape along the combined cross-section (based on mean, max & min values)
#
# For more information regarding the functions used here uncomment the following line.

# %%
#help(morpho.extractSection)
#help(morpho.statProfiles)

# %%
xlist = [None] * nbCS
xmaxlist = [None] * nbCS
zlist = np.zeros((nbCS,nbPts))
if x_axis: 
    dx = (xmax - xmin)/(nbCS-1)
else:
    dx = (ymax - ymin)/(nbCS-1)
    
zmin = np.zeros((len(timeStp),nbPts))
zmean = np.zeros((len(timeStp),nbPts))
zmax = np.zeros((len(timeStp),nbPts))

for t in range(len(timeStp)):
    step = timeStp[t]
    morpho.loadHDF5(timestep=step)

    for i in range(0,nbCS):
        xlist[i] = xmin+i*dx
        if x_axis:
            dist, zlist[i,:] = morpho.extractSection(xo = xlist[i], yo = ymin, xm = xlist[i], ym = ymax, pts = nbPts, vData = morpho.z, 
                       view = False, width = 800, height = 400, color = 'black', linesize = 3, 
                       markersize = 1, title = 'X-Cross section %d'% step)
        else:
            dist, zlist[i,:] = morpho.extractSection(xo = xmin, yo = xlist[i], xm = xmax, ym = xlist[i], pts = nbPts, vData = morpho.z, 
                       view = False, width = 800, height = 400, color = 'black', linesize = 3, 
                       markersize = 1, title = 'Y-Cross section %d'% step)
            
    if timeMA[t] > 0.: 
        color = 'rgba(104, 192, 98, 0.4)'
    else:
        color = 'rgba(243, 133, 79, 0.4)'
    zmin[t,:], zmean[t,:], zmax[t,:] = morpho.statProfiles(pData = zlist, pDist = dist, width = 1000, height = 500, 
                   color = color, linesize = 3, title = 'Analyse sections time: %5.0f Ka' %timeMA[t])
# Out:
# <div>                            <div id="d9b64517-2771-4384-859d-99c6f3a0bfde" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d9b64517-2771-4384-859d-99c6f3a0bfde")) {                    Plotly.newPlot(                        "d9b64517-2771-4384-859d-99c6f3a0bfde",                        [{"line":{"color":"rgb(0, 0, 0)","shape":"spline","width":0.5},"mode":"lines","name":"max","x":[0.0,62.89033555144479,125.78067110288958,188.67100665433472,251.56134220577957,314.4516777572244,377.3420133086691,440.2323488601139,503.12268441155913,566.0130199630039,628.9033555144488,691.7936910658935,754.6840266173382,817.5743621687834,880.4646977202282,943.355033271673,1006.2453688231178,1069.1357043745625,1132.0260399260078,1194.9163754774524,1257.8067110288976,1320.6970465803422,1383.587382131787,1446.4777176832322,1509.3680532346766,1572.2583887861217,1635.1487243375666,1698.0390598890115,1760.9293954404563,1823.8197309919015,1886.710066543346,1949.600402094791,2012.4907376462356,2075.3810731976805,2138.2714087491254,2201.1617443005707,2264.052079852015,2326.9424154034605,2389.832750954905,2452.7230865063502,2515.613422057795,2578.5037576092395,2641.394093160685,2704.2844287121293,2767.1747642635746,2830.065099815019,2892.955435366464,2955.845770917909,3018.736106469353,3081.626442020
244.879326062395,9307.76966161384,9370.659997165285,9433.55033271673,9496.440668268175,9559.33100381962,9622.221339371064,9685.11167492251,9748.002010473954,9810.892346025401,9873.782681576846,9936.67301712829,9999.563352679734,10062.45368823118,10125.344023782625,10188.234359334068,10251.124694885515,10314.015030436958,10376.905365988403,10439.795701539848,10502.686037091293,10565.576372642738,10628.466708194183,10691.357043745627,10754.247379297072,10817.137714848517,10880.028050399962,10942.918385951409,11005.808721502854,11068.699057054298,11131.589392605743,11194.479728157188,11257.370063708631,11320.260399260076,11383.150734811521,11446.041070362966,11508.93140591441,11571.821741465856,11634.7120770173,11697.602412568744,11760.492 ...

# %% [markdown]
# ## 4.1. Evolution of profile elevation with time
#
# We can create other plots for example the evolution of the maximum value of the min, mean, & max profile through time.

# %%
zz = np.zeros((3,len(timeStp)))

zz[0,:] = np.amax(zmin, axis=1)
zz[1,:] = np.amax(zmean, axis=1)
zz[2,:] = np.amax(zmax, axis=1)

# %%
morpho.timeProfiles(pData = zz, pDist = timeMA, width = 800, height = 500, linesize = 3,
                    title = 'Averaged Evolution through Time')
# Out:
# <div>                            <div id="0749be4d-3485-44fe-8117-6f613c27abef" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0749be4d-3485-44fe-8117-6f613c27abef")) {                    Plotly.newPlot(                        "0749be4d-3485-44fe-8117-6f613c27abef",                        [{"line":{"shape":"spline","width":3},"mode":"lines","x":[0.01,0.05,0.1],"y":[2741.29645218078,2736.2272900857474,2733.813440602239],"type":"scatter"},{"line":{"shape":"spline","width":3},"mode":"lines","x":[0.01,0.05,0.1],"y":[2742.045229623463,2737.785344383024,2735.6999290420717],"type":"scatter"},{"line":{"shape":"spline","width":3},"mode":"lines","x":[0.01,0.05,0.1],"y":[2743.6704961186188,2739.7650084334587,2738.015533132244],"type":"scatter"}],                        {"height":500,"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d ...

# %% [markdown]
# # 4.2. Position of maximum profiles along an axis
#
# Or the position of a given value from the different profiles with time.

# %%
zpos = np.zeros((3,len(timeStp)))
zpos[0,:] = dist[np.argmax(zmin, axis=1)] / (ymax-ymin)
zpos[1,:] = dist[np.argmax(zmean, axis=1)] / (ymax-ymin)
zpos[2,:] = dist[np.argmax(zmax, axis=1)] / (ymax-ymin)

# %%
morpho.timeProfiles(pData = zpos, pDist = timeMA, width = 1000, height = 600, linesize = 3,
                    title = 'Position of min, mean & max profile through Time')
# Out:
# <div>                            <div id="8e00f85e-0d00-4dd7-a50e-1cde26f20a30" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8e00f85e-0d00-4dd7-a50e-1cde26f20a30")) {                    Plotly.newPlot(                        "8e00f85e-0d00-4dd7-a50e-1cde26f20a30",                        [{"line":{"shape":"spline","width":3},"mode":"lines","x":[1,25,50,75,100],"y":[2.00745951080212,2.00745951080212,2.00745951080212,2.00745951080212,2.00745951080212],"type":"scatter"},{"line":{"shape":"spline","width":3},"mode":"lines","x":[1,25,50,75,100],"y":[2.00745951080212,2.00745951080212,2.00745951080212,2.00745951080212,2.00745951080212],"type":"scatter"},{"line":{"shape":"spline","width":3},"mode":"lines","x":[1,25,50,75,100],"y":[2.0049438973800626,2.0049438973800626,2.0049438973800626,2.0049438973800626,2.0049438973800626],"type":"scatter"}],                        {"height":600,"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar" ...

# %% [markdown]
# ## Discharge and Sedload Analysis

# %%
help(morpho)
#help(morpho.getParams)

# %%
# morpho.Zbc.shape
morpho.Zbc = morpho._assignBCs()

# %%
def getParams(morpho):
    """
    Define aspect, gradient and horizontal/vertical curvature using a
    quadratic polynomial method.
    """

    # Assign boundary conditions
    morpho.Zbc = np.zeros((morpho.ny + 2, morpho.nx + 2))
    morpho.Zbc[1:-1,1:-1] = morpho.z

    # Assign boundary conditions - sides
    morpho.Zbc[0, 1:-1] = morpho.z[0, :]
    morpho.Zbc[-1, 1:-1] = morpho.z[-1, :]
    morpho.Zbc[1:-1, 0] = morpho.z[:, 0]
    morpho.Zbc[1:-1, -1] = morpho.z[:,-1]

    # Assign boundary conditions - corners
    morpho.Zbc[0, 0] = morpho.z[0, 0]
    morpho.Zbc[0, -1] = morpho.z[0, -1]
    morpho.Zbc[-1, 0] = morpho.z[-1, 0]
    morpho.Zbc[-1, -1] = morpho.z[-1, 0]

    # Neighborhood definition
    # z1     z2     z3
    # z4     z5     z6
    # z7     z8     z9
    z1 = morpho.Zbc[2:, :-2]
    z2 = morpho.Zbc[2:,1:-1]
    z3 = morpho.Zbc[2:,2:]
    z4 = morpho.Zbc[1:-1, :-2]
    z5 = morpho.Zbc[1:-1,1:-1]
    z6 = morpho.Zbc[1:-1, 2:]
    z7 = morpho.Zbc[:-2, :-2]
    z8 = morpho.Zbc[:-2, 1:-1]
    z9 = morpho.Zbc[:-2, 2:]

    # Compute coefficient values
    zz = z2+z5
    r = ((z1+z3+z4+z6+z7+z9)-2.*(z2+z5+z8))/(3. * morpho.dx**2)
    t = ((z1+z2+z3+z7+z8+z9)-2.*(z4+z5+z6))/(3. * morpho.dx**2)
    s = (z3+z7-z1-z9)/(4. * morpho.dx**2)
    p = (z3+z6+z9-z1-z4-z7)/(6.*morpho.dx)
    q = (z1+z2+z3-z7-z8-z9)/(6.*morpho.dx)
    u = (5.*z1+2.*(z2+z4+z6+z8)-z1-z3-z7-z9)/9.
    #
    with np.errstate(invalid='ignore',divide='ignore'):
        morpho.grad = np.arctan(np.sqrt(p**2+q**2))
        morpho.aspect = np.arctan(q/p)
        morpho.hcurv = -(r*q**2-2.*p*q*s+t*p**2) / \
            ((p**2+q**2)*np.sqrt(1+p**2+q**2))
        morpho.vcurv = -(r*p**2+2.*p*q*s+t*q**2) /  \
            ((p**2+q**2)*np.sqrt(1+p**2+q**2))

    return

getParams(morpho)

# %%
#Vertical Curvature
plt.figure(figsize=(10, 8))
plt.imshow(morpho.vcurv,vmin=-0.005, vmax=0.005, cmap='seismic')
plt.colorbar()

# %%
#Horizontal Curvature
plt.figure(figsize=(10, 8))
plt.imshow(morpho.hcurv,vmin=-0.005, vmax=0.005, cmap='seismic')
plt.colorbar()

# %%
#Gradient
plt.figure(figsize=(10, 8))
plt.imshow(morpho.grad, cmap='seismic')
plt.colorbar()

# %%
plt.imshow(morpho.aspect)

# %%
plt.imshow(morpho.discharge)

# %%
plt.imshow(morpho.iceTH)
